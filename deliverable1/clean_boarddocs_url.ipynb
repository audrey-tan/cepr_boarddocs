# %% [markdown]
# This notebook visits the scraped links and get the name and address fields.
#
# Input:
# - `working_school_districts_with_boarddocs_scraped.csv`
#
# Output:
# - `boarddocs_url_cleaned.csv`

# %%
import pandas as pd

input_filename = "working_school_districts_with_boarddocs_scraped.csv"
boarddocs_df = pd.read_csv(input_filename)
boarddocs_df.sample(10)
# Out:
#                                              LEA_NAME    LEAID      STATENAME  \
# 8959             Vista Condor Global Academy District   601760     CALIFORNIA
# 19208                                         Holyoke  2506270  MASSACHUSETTS
# 7838                      North Orange County ROP JPA   601364     CALIFORNIA
# 6980                      EDUCATIONAL SERVICE UNIT 02  3180020       NEBRASKA
# 18292                                 LACLEDE CO. R-I  2910110       MISSOURI
# 11165            Enterprise Academy/Newport News City  5100073       VIRGINIA
# 13837                            Hardin County CUSD 1  1718200       ILLINOIS
# 4807                          Pioneer School District  5306750     WASHINGTON
# 17430              High Tech High Media Arts District   601515     CALIFORNIA
# 225    Yavapai County Juvenile Justice Center (79533)   400460        ARIZONA
#
#                                                                                                                                                                     url
# 8959                                      https://go.boarddocs.com/ca/rcoe/Board.nsf/files/D2U2PK0326F5/$file/RCOE%20Staff%20Report-Vista%20Lago%20Global%20Academy.pdf
# 19208                                                   https://go.boarddocs.com/co/cde/Board.nsf/files/9WSAFU6689EC/$file/Holyoke%20Innovation%20Application.Final.pdf
# 7838                                                                                              https://go.boarddocs.com/ca/tcrop/Board.nsf/goto?open&id=BGCVDZ80512F
# 6980                                                           https://go.boarddocs.com/co/cde/Board.nsf/files/CB7SXS736699/$file/1%20CCR%20301-8%20Clean%20Version.pdf
# 18292                                                         https://go.boarddocs.com/mo/foxc6/Board.nsf/files/CLX4GL0B7F3E/$file/01%20MUSIC%20Member%20Map%202022.pdf
# 11165                                                   https://go.boarddocs.com/vsba/nnps/Board.nsf/legacy-content/8963QR76FDA8/$FILE/Regular%20Session%2005.21.07.doc
# 13837                                                      https://go.boarddocs.com/il/oths/Board.nsf/files/DAXJKQ4D7813/$file/2024.11%202024%20Tax%20Levy%20Packet.pdf
# 4807                                                                                                        https://go.boarddocs.com/ny/pioneerschools/Board.nsf/Public
# 17430  https://www.boarddocs.com/ca/sandi/Board.nsf/files/AJ7VB87F6071/$file/Attach%202%20Disclosure%20of%20District%20Investments%20Ending%20December%2031,%202016.pdf
# 225                                                                                                                                                                 NaN

# %%
# get the url
urls = set(boarddocs_df["url"])

# %%
# number of urls
len(urls)
# Out:
# 9472

# %%
from urllib.parse import urlparse

def extract_domain(url):
    try:
        domain = urlparse(url).netloc
        return domain
    except Exception as e:
        return None

# Example usage:
domains = set([extract_domain(url) for url in urls])
domains
# Out:
# {None, 'cdn.boarddocs.com', 'go.boarddocs.com', 'www.boarddocs.com'}

# %%
# let's check out the cdn
boarddocs_df['domain'] = boarddocs_df["url"].apply(extract_domain)

# %%
# Set the option to display all columns
pd.set_option('display.max_columns', None)

# (Optional) Set the maximum width of each column to prevent truncation
pd.set_option('display.max_colwidth', None)

# %%
boarddocs_df[boarddocs_df['domain'] == "cdn.boarddocs.com"]
# Out:
#                                                            LEA_NAME    LEAID  \
# 4874                                      Shonto Preparatory School  5900128
# 5598                              St. Coletta Special Education PCS  1100064
# 5704                                         Cedar Tree Academy PCS  1100029
# 6357   TEACH Prep Mildred S. Cunningham & Edith H. Morris Elem DIST   601575
# 6389                             Imagine Prep Coolidge Inc. (90034)   400769
# 6905                                     Skyview School Inc. (4496)   400093
# 9603                         HARBOR SCIENCE AND ARTS CHARTER SCHOOL  3600047
# 9623                              STOREFRONT ACADEMY CHARTER SCHOOL  3601137
# 10189                                        Curlew School District  5301890
# 10783    Valley Academy for Career and Technology Education (79397)   400341
# 12348                                               Bleckley County  1300440
# 12430      Ridgecrest Elem Acad for Language Music and Sci District   601931
# 12561                           Theodore Jamerson Elementary School  5900096
# 12907                      Ann Jerkins-Harris Academy of Excellence  3901502
# 13562                                                  Riverside SD  4223250
# 14550                              SOUTHSIDE ACADEMY CHARTER SCHOOL  3600070
# 14727                                                          GORE  4012900
# 16716                                               Judith Gap Elem  3015360
# 17443                               Paul R Brown Leadership Academy  3700351
# 18644                                  Northeast Dubois Co Sch Corp  1808120
# 18800                                 ACADEMY OF SEMINOLE (CHARTER)  4000803
# 19013                                              Da Vinci Schools  2600088
#
#                         STATENAME  \
# 4874   BUREAU OF INDIAN EDUCATION
# 5598         DISTRICT OF COLUMBIA
# 5704         DISTRICT OF COLUMBIA
# 6357                   CALIFORNIA
# 6389                      ARIZONA
# 6905                      ARIZONA
# 9603                     NEW YORK
# 9623                     NEW YORK
# 10189                  WASHINGTON
# 10783                     ARIZONA
# 12348                     GEORGIA
# 12430                  CALIFORNIA
# 12561  BUREAU OF INDIAN EDUCATION
# 12907                        OHIO
# 13562                PENNSYLVANIA
# 14550                    NEW YORK
# 14727                    OKLAHOMA
# 16716                     MONTANA
# 17443              NORTH CAROLINA
# 18644                     INDIANA
# 18800                    OKLAHOMA
# 19013                    MICHIGAN
#
#                                                                                        url  \
# 4874         https://cdn.boarddocs.com/sites/fl/pcsfl/2010/Attachments/Attachment-3349.pdf
# 5598       https://cdn.boarddocs.com/sites/fl/pcsfl/2017/Agendas/Documents/Agenda-1291.pdf
# 5704         https://cdn.boarddocs.com/sites/fl/pcsfl/2017/Attachments/Attachment-7964.pdf
# 6357         https://cdn.boarddocs.com/sites/fl/pcsfl/2009/Attachments/Attachment-2245.pdf
# 6389         https://cdn.boarddocs.com/sites/fl/pcsfl/2010/Attachments/Attachment-3349.pdf
# 6905   https://cdn.boarddocs.com/sites/fl/pcsfl/2014/Resolutions/ResolutionsByMeeting.html
# 9603         https://cdn.boarddocs.com/sites/fl/pcsfl/2014/Attachments/Attachment-5954.pdf
# 9623         https://cdn.boarddocs.com/sites/fl/pcsfl/2017/Attachments/Attachment-7964.pdf
# 10189        https://cdn.boarddocs.com/sites/fl/pcsfl/2009/Attachments/Attachment-1556.pdf
# 10783      https://cdn.boarddocs.com/sites/fl/pcsfl/2009/Agendas/Documents/Agenda-1045.pdf
# 12348        https://cdn.boarddocs.com/sites/fl/pcsfl/2009/Attachments/Attachment-2139.pdf
# 12430        https://cdn.boarddocs.com/sites/fl/pcsfl/2012/Attachments/Attachment-5174.pdf
# 12561        https://cdn.boarddocs.com/sites/fl/pcsfl/2018/Attachments/Attachment-8435.pdf
# 12907        https://cdn.boarddocs.com/sites/fl/pcsfl/2016/Attachments/Attachment-7580.pdf
# 13562        https://cdn.boarddocs.com/sites/fl/pcsfl/2009/Attachments/Attachment-1900.pdf
# 14550         https://cdn.boarddocs.com/sites/fl/pcsfl/2013/Media/2511/VideoMain-2511.html
# 14727        https://cdn.boarddocs.com/sites/fl/pcsfl/2012/Attachments/Attachment-4493.pdf
# 16716        https://cdn.boarddocs.com/sites/fl/pcsfl/2017/Attachments/Attachment-7818.pdf
# 17443        https://cdn.boarddocs.com/sites/fl/pcsfl/2009/Attachments/Attachment-1880.pdf
# 18644        https://cdn.boarddocs.com/sites/fl/pcsfl/2009/Attachments/Attachment-1675.pdf
# 18800        https://cdn.boarddocs.com/sites/fl/pcsfl/2011/Attachments/Attachment-3872.pdf
# 19013        https://cdn.boarddocs.com/sites/fl/pcsfl/2010/Attachments/Attachment-2843.pdf
#
#                   domain
# 4874   cdn.boarddocs.com
# 5598   cdn.boarddocs.com
# 5704   cdn.boarddocs.com
# 6357   cdn.boarddocs.com
# 6389   cdn.boarddocs.com
# 6905   cdn.boarddocs.com
# 9603   cdn.boarddocs.com
# 9623   cdn.boarddocs.com
# 10189  cdn.boarddocs.com
# 10783  cdn.boarddocs.com
# 12348  cdn.boarddocs.com
# 12430  cdn.boarddocs.com
# 12561  cdn.boarddocs.com
# 12907  cdn.boarddocs.com
# 13562  cdn.boarddocs.com
# 14550  cdn.boarddocs.com
# 14727  cdn.boarddocs.com
# 16716  cdn.boarddocs.com
# 17443  cdn.boarddocs.com
# 18644  cdn.boarddocs.com
# 18800  cdn.boarddocs.com
# 19013  cdn.boarddocs.com

# %%
# we will keep the cdn in mind and parse the state and lea agency after
boarddocs_df[boarddocs_df['domain'] == "www.boarddocs.com"].head()
# Out:
#                                    LEA_NAME    LEAID   STATENAME  \
# 4794                          Dallas County   101110     ALABAMA
# 4796  Stanislaus County Office of Education   691041  CALIFORNIA
# 4808                        Rootstown Local  3904921        OHIO
# 4813                           Griffin RESA  1300012     GEORGIA
# 4814     CONNETQUOT CENTRAL SCHOOL DISTRICT  3608160    NEW YORK
#
#                                                                                                                                                      url  \
# 4794  https://www.boarddocs.com/tx/disd/Board.nsf/files/BFQT4W707EF4/$file/Resolution%20Approving%20Dallas%20County%20Elections%20Voting%20Equipment.pdf
# 4796                                                   https://www.boarddocs.com/ca/sccoe/Board.nsf/files/BPMMV65CCD1E/$file/CSBA_PGSBrochure_County.pdf
# 4808                                                                                 https://www.boarddocs.com/oh/root/Board.nsf/Public?open&id=policies
# 4813                              https://www.boarddocs.com/ga/fcss/Board.nsf/files/8TFTCR76C17B/%24file/CCGPS%20Revised%20Board%20presentationFINAL.pdf
# 4814                                                                                          https://www.boarddocs.com/ny/ccsdli/Board.nsf/vpublic?open
#
#                  domain
# 4794  www.boarddocs.com
# 4796  www.boarddocs.com
# 4808  www.boarddocs.com
# 4813  www.boarddocs.com
# 4814  www.boarddocs.com

# %%
boarddocs_df[boarddocs_df['domain'] == "go.boarddocs.com"].head()
# Out:
#                               LEA_NAME    LEAID     STATENAME  \
# 4774  RICHFIELD PUBLIC SCHOOL DISTRICT  2731750     MINNESOTA
# 4775   Impact | Puget Sound Elementary  5300345    WASHINGTON
# 4776               Coatesville Area SD  4206240  PENNSYLVANIA
# 4777                      DONIPHAN R-I  2910920      MISSOURI
# 4778                    Rapides Parish  2201290     LOUISIANA
#
#                                                                                                                                                    url  \
# 4774                                  https://go.boarddocs.com/ar/nlrsd/Board.nsf/files/CDDUUN7DC4F2/$file/2019-07-11%20Special%20Meeting%20Agenda.pdf
# 4775  https://go.boarddocs.com/nc/cart/Board.nsf/files/AY4GCU433316/$file/BSES_Items%20for%20Discussion%20with%20Board%20of%20Education-May%202018.pdf
# 4776                                                                                           https://go.boarddocs.com/pa/coat/Board.nsf/vpublic?open
# 4777                                         https://go.boarddocs.com/mo/foxc6/Board.nsf/files/CLX4GL0B7F3E/$file/01%20MUSIC%20Member%20Map%202022.pdf
# 4778                                                                                           https://go.boarddocs.com/la/rpsb/Board.nsf/vpublic?open
#
#                 domain
# 4774  go.boarddocs.com
# 4775  go.boarddocs.com
# 4776  go.boarddocs.com
# 4777  go.boarddocs.com
# 4778  go.boarddocs.com

# %%
def get_url_parts(url):
    try:
        path = urlparse(url).path
        parts = path.strip('/').split('/')
        return parts
    except Exception as e:
        return [None, None, None]


boarddocs_df["boarddocs_state"] = boarddocs_df["url"].apply(lambda row: get_url_parts(row)[0])
boarddocs_df.sample(5)
# Out:
#                                 LEA_NAME    LEAID  STATENAME  \
# 12756                        LEANDER ISD  4827030      TEXAS
# 6911           Dept of Corrections-Youth  3000091    MONTANA
# 11736  Canton College Preparatory School  3901470       OHIO
# 2411   LA CRESCENT-HOKAH SCHOOL DISTRICT  2717250  MINNESOTA
# 3626             Northwood Local Schools  3905071       OHIO
#
#                                                                                                                                            url  \
# 12756                       https://www.boarddocs.com/tx/rrisd/Board.nsf/files/AM9K224FA451/$file/D2.Board%20Meeting%20051117_HRS%20slides.pdf
# 6911                                 https://go.boarddocs.com/me/sport/Board.nsf/files/CC7JP24E131C/$file/LD%20756%20Morales%20amend%203-3.pdf
# 11736  https://go.boarddocs.com/co/cde/Board.nsf/files/D3U8SD1FB028/$file/Appendices%20REVISED%20Submission%20with%20highlighted%20changes.pdf
# 2411                                                                                                                                       NaN
# 3626                                                                                                                                       NaN
#
#                   domain boarddocs_state
# 12756  www.boarddocs.com              tx
# 6911    go.boarddocs.com              me
# 11736   go.boarddocs.com              co
# 2411                None            None
# 3626                None            None

# %%
# for cdn its the second argument
boarddocs_df.loc[boarddocs_df['domain']=='cdn.boarddocs.com', "boarddocs_state"] = boarddocs_df["url"].apply(lambda row: get_url_parts(row)[1])
boarddocs_df.loc[boarddocs_df['domain']=='cdn.boarddocs.com',].sample(5)
# Out:
#                                                        LEA_NAME    LEAID  \
# 5704                                     Cedar Tree Academy PCS  1100029
# 13562                                              Riverside SD  4223250
# 19013                                          Da Vinci Schools  2600088
# 12430  Ridgecrest Elem Acad for Language Music and Sci District   601931
# 17443                           Paul R Brown Leadership Academy  3700351
#
#                   STATENAME  \
# 5704   DISTRICT OF COLUMBIA
# 13562          PENNSYLVANIA
# 19013              MICHIGAN
# 12430            CALIFORNIA
# 17443        NORTH CAROLINA
#
#                                                                                  url  \
# 5704   https://cdn.boarddocs.com/sites/fl/pcsfl/2017/Attachments/Attachment-7964.pdf
# 13562  https://cdn.boarddocs.com/sites/fl/pcsfl/2009/Attachments/Attachment-1900.pdf
# 19013  https://cdn.boarddocs.com/sites/fl/pcsfl/2010/Attachments/Attachment-2843.pdf
# 12430  https://cdn.boarddocs.com/sites/fl/pcsfl/2012/Attachments/Attachment-5174.pdf
# 17443  https://cdn.boarddocs.com/sites/fl/pcsfl/2009/Attachments/Attachment-1880.pdf
#
#                   domain boarddocs_state
# 5704   cdn.boarddocs.com              fl
# 13562  cdn.boarddocs.com              fl
# 19013  cdn.boarddocs.com              fl
# 12430  cdn.boarddocs.com              fl
# 17443  cdn.boarddocs.com              fl

# %%
boarddocs_df["boarddocs_lea"] = boarddocs_df["url"].apply(lambda row: get_url_parts(row)[1])
boarddocs_df.sample(5)
# Out:
#                                             LEA_NAME    LEAID   STATENAME  \
# 9718              TWO DIMENSIONS PREPARATORY ACADEMY  4800069       TEXAS
# 10092  California Virtual Academy at Fresno District   601616  CALIFORNIA
# 9655                     South Shore School District  5512030   WISCONSIN
# 3284   SCHUYLER-STEUBEN-CHEMUNG-TIOGA-ALLEGANY BOCES  3680780    NEW YORK
# 17217                                   S AND S CISD  4838400       TEXAS
#
#                                                                                                                                            url  \
# 9718                              https://go.boarddocs.com/pa/wood/Board.nsf/files/CBMJ3S4B1BF6/$file/Curriculum%20Guide%2022-23.DRAFT.v.3.pdf
# 10092  https://go.boarddocs.com/ca/socccd/Board.nsf/files/CF7PST6547A0/$file/EXH%20A%20SOCCCD%20SC%20CCAP%20SVUSD%20Appendix%20Fall%202022.pdf
# 9655                                                                                       https://go.boarddocs.com/wi/sshore/Board.nsf/Public
# 3284                                                                                                                                       NaN
# 17217                                 https://go.boarddocs.com/ca/smusd/Board.nsf/files/CKUNSK615503/$file/Calendar%20%20Draft%202024-2025.pdf
#
#                  domain boarddocs_state boarddocs_lea
# 9718   go.boarddocs.com              pa          wood
# 10092  go.boarddocs.com              ca        socccd
# 9655   go.boarddocs.com              wi        sshore
# 3284               None            None          None
# 17217  go.boarddocs.com              ca         smusd

# %%
# for cdn its the third argument
def func1(row):
    parts = get_url_parts(row)
    if len(parts) < 3:
        print(row)
        return None
    return parts[2]

boarddocs_df.loc[boarddocs_df['domain']=='cdn.boarddocs.com', "boarddocs_lea"] = boarddocs_df["url"].apply(func1)
boarddocs_df.loc[boarddocs_df['domain']=='cdn.boarddocs.com',].sample(5)
# Out:
# https://www.boarddocs.com/Home.nsf/blog
#                                        LEA_NAME    LEAID  \
# 5598          St. Coletta Special Education PCS  1100064
# 17443           Paul R Brown Leadership Academy  3700351
# 12907  Ann Jerkins-Harris Academy of Excellence  3901502
# 14550          SOUTHSIDE ACADEMY CHARTER SCHOOL  3600070
# 18644              Northeast Dubois Co Sch Corp  1808120
#
#                   STATENAME  \
# 5598   DISTRICT OF COLUMBIA
# 17443        NORTH CAROLINA
# 12907                  OHIO
# 14550              NEW YORK
# 18644               INDIANA
#
#                                                                                    url  \
# 5598   https://cdn.boarddocs.com/sites/fl/pcsfl/2017/Agendas/Documents/Agenda-1291.pdf
# 17443    https://cdn.boarddocs.com/sites/fl/pcsfl/2009/Attachments/Attachment-1880.pdf
# 12907    https://cdn.boarddocs.com/sites/fl/pcsfl/2016/Attachments/Attachment-7580.pdf
# 14550     https://cdn.boarddocs.com/sites/fl/pcsfl/2013/Media/2511/VideoMain-2511.html
# 18644    https://cdn.boarddocs.com/sites/fl/pcsfl/2009/Attachments/Attachment-1675.pdf
#
#                   domain boarddocs_state boarddocs_lea
# 5598   cdn.boarddocs.com              fl         pcsfl
# 17443  cdn.boarddocs.com              fl         pcsfl
# 12907  cdn.boarddocs.com              fl         pcsfl
# 14550  cdn.boarddocs.com              fl         pcsfl
# 18644  cdn.boarddocs.com              fl         pcsfl

# %%
# the https://www.boarddocs.com/Home.nsf/blog is a flop
# delete that url
boarddocs_df.loc[boarddocs_df['url']=='https://www.boarddocs.com/Home.nsf/blog', "boarddocs_state"] = None
boarddocs_df.loc[boarddocs_df['url']=='https://www.boarddocs.com/Home.nsf/blog', "domain"] = None
boarddocs_df.loc[boarddocs_df['url']=='https://www.boarddocs.com/Home.nsf/blog', "boarddocs_lea"] = None
boarddocs_df.loc[boarddocs_df['url']=='https://www.boarddocs.com/Home.nsf/blog', "url"] = None

# %%
# get the states parsed and their counts as a dictionary
state_counts_dict = boarddocs_df["boarddocs_state"].value_counts().to_dict()
print(state_counts_dict)
# Out:
# {'ca': 2046, 'ny': 1077, 'oh': 1000, 'pa': 976, 'il': 749, 'co': 685, 'tx': 679, 'mo': 589, 'mi': 572, 'wi': 556, 'vsba': 545, 'nj': 505, 'fl': 421, 'in': 360, 'la': 358, 'wa': 342, 'mabe': 285, 'ks': 273, 'ia': 218, 'ga': 211, 'nc': 186, 'az': 174, 'nv': 173, 'ut': 131, 'ma': 130, 'id': 127, 'mt': 116, 'sc': 111, 'wy': 102, 'ct': 101, 'tn': 100, 'mn': 99, 'ak': 92, 'fla': 85, 'ar': 82, 'va': 69, 'wv': 67, 'nm': 67, 'me': 60, 'nh': 57, 'ok': 50, 'or': 42, 'ri': 39, 'sd': 32, 'de': 29, 'ms': 15, 'nd': 15, 'md': 14, 'OH': 10, 'vt': 8, 'WA': 5, 'can': 5, 'butler': 4, 'psba': 4, 'wcps': 3, 'support': 2, 'genoa': 2, 'MI': 2, 'CA': 1, 'FLA': 1, 'NJ': 1, 'IL': 1, 'sufsd': 1}

# %%
# here are ones that stood out
weird_state_names = ['vsba', 'mabe', 'fla', 'can', 'psba', 'butler', 'wcps', 'support', 'genoa', 'FLA','Home.nsf','sufsd']

# %%
pd.set_option('display.max_colwidth',None)

# %%
boarddocs_df.loc[boarddocs_df['boarddocs_state']=='vsba',].head()
# Out:
#                               LEA_NAME    LEAID STATENAME  \
# 4847      Staunton City Public Schools  5103690  VIRGINIA
# 4881            NORFOLK PUBLIC SCHOOLS  3174430  NEBRASKA
# 4899    Tazewell County Public Schools  5103810  VIRGINIA
# 4923  Cumberland County Public Schools  5101080  VIRGINIA
# 4925            Central State Hospital  5100045  VIRGINIA
#
#                                                                                                                                                                     url  \
# 4847                                                https://go.boarddocs.com/vsba/waynesboro/Board.nsf/files/D64LP6577715/$file/SAW%20School%20Boards%20UWSAW%20MOU.pdf
# 4881                                                                                             https://www.boarddocs.com/vsba/nps/Board.nsf/goto?open&id=89476K57C109
# 4899                                                                              https://go.boarddocs.com/vsba/roecnty/Board.nsf/files/C62MPK59A63D/$file/163-21b.xlsx
# 4923                                                                                                              https://go.boarddocs.com/vsba/ccpsva/Board.nsf/Public
# 4925  https://go.boarddocs.com/vsba/pitpsva/Board.nsf/files/CL2QSS6ABFB1/$file/2-16-22%20Minutes%20-%20PCPS%20Board%20Regular%20Meeting%20(Approved%20and%20Signed).pdf
#
#                  domain boarddocs_state boarddocs_lea
# 4847   go.boarddocs.com            vsba    waynesboro
# 4881  www.boarddocs.com            vsba           nps
# 4899   go.boarddocs.com            vsba       roecnty
# 4923   go.boarddocs.com            vsba        ccpsva
# 4925   go.boarddocs.com            vsba       pitpsva

# %%
# vsba is ok, probably means Virginia School Board Association
weird_state_names.remove("vsba")
next_weird_state_name = weird_state_names[0]
next_weird_state_name
# Out:
# 'mabe'

# %%
boarddocs_df.loc[boarddocs_df['boarddocs_state']=='mabe',].head()
# Out:
#                               LEA_NAME    LEAID   STATENAME  \
# 4826  Greater Brunswick Charter School  3400047  NEW JERSEY
# 4838                    Hopkins County  2102860    KENTUCKY
# 4852                        Denton H S  3008850     MONTANA
# 4943                     Kenton County  2103090    KENTUCKY
# 4958      OAKLAND CRAIG PUBLIC SCHOOLS  3174640    NEBRASKA
#
#                                                                                                                                           url  \
# 4826  https://www.boarddocs.com/mabe/fcps/Board.nsf/files/CAUQ5L65A834/$file/01.26.22%20MVMPCS%20Application%20for%20Expansion_backup%202.pdf
# 4838                  https://www.boarddocs.com/mabe/mcpsmd/Board.nsf/files/AX5HMA48778D/$file/Curr%20Review%20JHU%20Rpt%20Exec%20Summary.pdf
# 4852                                                                  https://go.boarddocs.com/mabe/carps/Board.nsf/goto?open&id=BCESGR72A800
# 4943   https://go.boarddocs.com/mabe/pgcps/Board.nsf/files/C82HSJ49E063/$file/CCAP%20-%20Zero%20Energy%20and%20Carbon%20Schools%20in%20MD.pdf
# 4958                               https://www.boarddocs.com/mabe/mcpsmd/Board.nsf/files/BR9MQ25C1961/$file/Retirement%20MCPS%20Personnel.pdf
#
#                  domain boarddocs_state boarddocs_lea
# 4826  www.boarddocs.com            mabe          fcps
# 4838  www.boarddocs.com            mabe        mcpsmd
# 4852   go.boarddocs.com            mabe         carps
# 4943   go.boarddocs.com            mabe         pgcps
# 4958  www.boarddocs.com            mabe        mcpsmd

# %%
# mabe is fine
# probably maryland board of education
weird_state_names.remove("mabe")
next_weird_state_name = weird_state_names[0]
next_weird_state_name
# Out:
# 'fla'

# %%
boarddocs_df.loc[boarddocs_df['boarddocs_state']=='fla',].head()
# Out:
#                                               LEA_NAME    LEAID   STATENAME  \
# 5274                             Pine Ridge Elementary   630390  CALIFORNIA
# 5393  CHAMPS - Charter HS of Arts-MULmedia & Perf DIST   601580  CALIFORNIA
# 5397                                          Copeland  2005190      KANSAS
# 5779                      Orange County Public Schools  5102820    VIRGINIA
# 5964                                        Moore Elem  3018870     MONTANA
#
#                                                                                                                    url  \
# 5274                https://go.boarddocs.com/fla/lake/Board.nsf/files/CNURQN680B02/$file/Board%20List%2002.13.2023.pdf
# 5393         https://www.boarddocs.com/fla/vcsfl/Board.nsf/files/A2DHTW48DBE4/$file/Application%20-%20Big%20Engine.pdf
# 5397              https://go.boarddocs.com/fla/vcsfl/Board.nsf/files/9FP3JQ717E5A/$file/Copeland%20Bio%2012-3-2013.pdf
# 5779  https://go.boarddocs.com/fla/orcpsfl/Board.nsf/files/CETM9F588798/$file/2024-25%20OCPS%20District%20Calendar.pdf
# 5964     https://go.boarddocs.com/fla/leon/Board.nsf/files/CNLJ894B2752/$file/WT%20Moore%20Phase%20III%20Documents.pdf
#
#                  domain boarddocs_state boarddocs_lea
# 5274   go.boarddocs.com             fla          lake
# 5393  www.boarddocs.com             fla         vcsfl
# 5397   go.boarddocs.com             fla         vcsfl
# 5779   go.boarddocs.com             fla       orcpsfl
# 5964   go.boarddocs.com             fla          leon

# %%
# fla is fine, they are florida schools
weird_state_names.remove("fla")
next_weird_state_name = weird_state_names[0]
next_weird_state_name
# Out:
# 'can'

# %%
boarddocs_df.loc[boarddocs_df['boarddocs_state']=='can',].head()
# Out:
#                                        LEA_NAME    LEAID     STATENAME  \
# 5895                            CANADIAN VALLEY  4000052      OKLAHOMA
# 10690                           CANADIAN VALLEY  4000062      OKLAHOMA
# 11923                             Highwood K-12  3014070       MONTANA
# 12161  THOUSAND ISLANDS CENTRAL SCHOOL DISTRICT  3607650      NEW YORK
# 17803                            LITTLE HEART 4  3811540  NORTH DAKOTA
#
#                                                                                                                                    url  \
# 5895                                                             https://go.boarddocs.com/can/fvrl/Board.nsf/goto?open&id=BKMQMQ64A488
# 10690                                                            https://go.boarddocs.com/can/fvrl/Board.nsf/goto?open&id=BKMQMQ64A488
# 11923  https://go.boarddocs.com/can/fsd38/Board.nsf/files/CCDNCK5F4A28/$file/Foothills%20School%20Division%20Capital%20Plan%202022.pdf
# 12161  https://go.boarddocs.com/can/ucdsb/Board.nsf/files/DAGM9L5A2A92/$file/PR432.1_AppendixD_VideoSurveillance_Locations_2024Oct.pdf
# 17803                   https://go.boarddocs.com/can/fsd38/Board.nsf/files/CKAMNR59FAEE/$file/C%20I%20McLaren%20School%20Ed%20Plan.pdf
#
#                  domain boarddocs_state boarddocs_lea
# 5895   go.boarddocs.com             can          fvrl
# 10690  go.boarddocs.com             can          fvrl
# 11923  go.boarddocs.com             can         fsd38
# 12161  go.boarddocs.com             can         ucdsb
# 17803  go.boarddocs.com             can         fsd38

# %%
# can is canadian schools
# we should remove them since we don't care about canadian schools in this project
boarddocs_df.loc[boarddocs_df['boarddocs_state']=='can', "boarddocs_lea"] = None
boarddocs_df.loc[boarddocs_df['boarddocs_state']=='can', "url"] = None
boarddocs_df.loc[boarddocs_df['boarddocs_state']=='can', "domain"] = None
boarddocs_df.loc[boarddocs_df['boarddocs_state']=='can', "boarddocs_state"] = None

# %%
weird_state_names.remove("can")
next_weird_state_name = weird_state_names[0]
next_weird_state_name
# Out:
# 'psba'

# %%
boarddocs_df.loc[boarddocs_df['boarddocs_state']=='psba',].head()
# Out:
#                               LEA_NAME    LEAID     STATENAME  \
# 5762                     Deer Lakes SD  4207540  PENNSYLVANIA
# 9155                       NURSERY ISD  4833270         TEXAS
# 12776  East Union Comm School District  1910350          IOWA
# 14255               Ligonier Valley SD  4213710  PENNSYLVANIA
#
#                                                                                                           url  \
# 5762                                                    https://go.boarddocs.com/psba/dlsdpa/Board.nsf/Public
# 9155   https://go.boarddocs.com/psba/dlsdpa/Board.nsf/files/CZDNJ260153D/$file/200-AR-1-Enrollment%20Form.pdf
# 12776                                https://go.boarddocs.com/psba/dlsdpa/Board.nsf/goto?open&id=CHZKKR52499D
# 14255        https://go.boarddocs.com/psba/dlsdpa/Board.nsf/files/CZDR6M6BA9ED/$file/808%20-%20AR%20-%201.pdf
#
#                  domain boarddocs_state boarddocs_lea
# 5762   go.boarddocs.com            psba        dlsdpa
# 9155   go.boarddocs.com            psba        dlsdpa
# 12776  go.boarddocs.com            psba        dlsdpa
# 14255  go.boarddocs.com            psba        dlsdpa

# %%
# psba probably means Pennsylvania School Boards Association
weird_state_names.remove("psba")
next_weird_state_name = weird_state_names[0]
next_weird_state_name
# Out:
# 'butler'

# %%
boarddocs_df.loc[boarddocs_df['boarddocs_state']=='butler',].head()
# Out:
#                                              LEA_NAME    LEAID STATENAME  \
# 6678                     TRI-COUNTY TECHNOLOGY CENTER  4000093  OKLAHOMA
# 9457                                  Knox County ESC  3904781      OHIO
# 11086  Butler Technology & Career Development Schools  3905088      OHIO
# 11544                   WES WATKINS TECHNOLOGY CENTER  4000065  OKLAHOMA
#
#                                                                                                                                                 url  \
# 6678                                 https://www.boarddocs.com/butler/Board.nsf/legacy-content/85BMP21D4F62/$FILE/Facilities%20Strategic%20Plan.pdf
# 9457   https://go.boarddocs.com/butler/Board.nsf/files/8HTP64630762/$file/March%2018%20Regular%20Meeting%20and%20March%2025%2C%201998%20Minutes.pdf
# 11086                                                                          https://www.boarddocs.com/butler/Board.nsf/goto?open&id=ABULPD570215
# 11544                                       https://go.boarddocs.com/butler/Board.nsf/files/8HESY56FFC3C/$file/October%2011%2C%202000%20Minutes.pdf
#
#                   domain boarddocs_state boarddocs_lea
# 6678   www.boarddocs.com          butler     Board.nsf
# 9457    go.boarddocs.com          butler     Board.nsf
# 11086  www.boarddocs.com          butler     Board.nsf
# 11544   go.boarddocs.com          butler     Board.nsf

# %%
# butler is fine. it is a school board association in ohio
weird_state_names.remove("butler")
weird_state_names
# Out:
# ['wcps', 'support', 'genoa', 'FLA', 'Home.nsf', 'sufsd']

# %%
boarddocs_df.loc[boarddocs_df['boarddocs_state']=='wcps',].head()
# Out:
#                      LEA_NAME    LEAID STATENAME  \
# 7172           Screven County  1304500   GEORGIA
# 11642  Northeast Georgia RESA  1300010   GEORGIA
# 17905   Heart of Georgia RESA  1300017   GEORGIA
#
#                                                                                                      url  \
# 7172            https://www.boarddocs.com/wcps/Board.nsf/legacy-content/87Y65T65066A/$FILE/Min021103.pdf
# 11642  https://www.boarddocs.com/wcps/Board.nsf/legacy-content/87XUQU642EAA/$FILE/ATT4CLAW/Min041806.pdf
# 17905  https://www.boarddocs.com/wcps/Board.nsf/legacy-content/87XUQU642EAA/$FILE/ATT4CLAW/Min041806.pdf
#
#                   domain boarddocs_state boarddocs_lea
# 7172   www.boarddocs.com            wcps     Board.nsf
# 11642  www.boarddocs.com            wcps     Board.nsf
# 17905  www.boarddocs.com            wcps     Board.nsf

# %%
# wcps is fine. Walton County Public Schools
weird_state_names.remove("wcps")
weird_state_names
# Out:
# ['support', 'genoa', 'FLA', 'Home.nsf', 'sufsd']

# %%
boarddocs_df.loc[boarddocs_df['boarddocs_state']=='support',].head()
# Out:
#                                                LEA_NAME    LEAID  STATENAME  \
# 7320   Carmen High School of Science and Technology Inc  5500076  WISCONSIN
# 15377                           Pickford Public Schools  2628020   MICHIGAN
#
#                                                                                                                        url  \
# 7320   https://go.boarddocs.com/support/plus/Board.nsf/files/CGAMSU5AD0EB/$file/Personnel%20Consent%20Agenda%206.21.22.pdf
# 15377  https://go.boarddocs.com/support/plus/Board.nsf/files/CGAMSU5AD0EB/$file/Personnel%20Consent%20Agenda%206.21.22.pdf
#
#                  domain boarddocs_state boarddocs_lea
# 7320   go.boarddocs.com         support          plus
# 15377  go.boarddocs.com         support          plus

# %%
# support is a demo website
# remove it
boarddocs_df.loc[boarddocs_df['boarddocs_state']=='support', "boarddocs_lea"] = None
boarddocs_df.loc[boarddocs_df['boarddocs_state']=='support', "url"] = None
boarddocs_df.loc[boarddocs_df['boarddocs_state']=='support', "domain"] = None
boarddocs_df.loc[boarddocs_df['boarddocs_state']=='support', "boarddocs_state"] = None

# %%
weird_state_names.remove("support")
weird_state_names
# Out:
# ['genoa', 'FLA', 'Home.nsf', 'sufsd']

# %%
boarddocs_df.loc[boarddocs_df['boarddocs_state']=='genoa',].head()
# Out:
#                          LEA_NAME    LEAID STATENAME  \
# 9638      Genoa Kingston CUSD 424  1716410  ILLINOIS
# 12273  Kishwaukee Educ Consortium  1700258  ILLINOIS
#
#                                                                                                                                   url  \
# 9638                                                                                  https://go.boarddocs.com/genoa/Board.nsf/Public
# 12273  https://go.boarddocs.com/genoa/Board.nsf/legacy-content/85WJVP121BB0/$FILE/082206%20%20%20Board%20of%20Education%20Minutes.pdf
#
#                  domain boarddocs_state boarddocs_lea
# 9638   go.boarddocs.com           genoa     Board.nsf
# 12273  go.boarddocs.com           genoa     Board.nsf

# %%
# genoa points towards a school board in Genoa, IL
# ok
weird_state_names.remove("genoa")
weird_state_names
# Out:
# ['FLA', 'Home.nsf', 'sufsd']

# %%
boarddocs_df.loc[boarddocs_df['boarddocs_state']=='FLA',].head()
# Out:
#                             LEA_NAME    LEAID   STATENAME  \
# 8941  North Wildwood School District  3411670  NEW JERSEY
#
#                                                                                                        url  \
# 8941  https://go.boarddocs.com/FLA/scsfl/Board.nsf/files/9P9LB4559728/$file/2014%2015%20Work%20Program.pdf
#
#                 domain boarddocs_state boarddocs_lea
# 8941  go.boarddocs.com             FLA         scsfl

# %%
# FLA is ok, florida
weird_state_names.remove("FLA")
weird_state_names
# Out:
# ['Home.nsf', 'sufsd']

# %%
boarddocs_df.loc[boarddocs_df['boarddocs_state']=='Home.nsf',].head()
# Out:
# Empty DataFrame
# Columns: [LEA_NAME, LEAID, STATENAME, url, domain, boarddocs_state, boarddocs_lea]
# Index: []

# %%
# probably previously removed
weird_state_names.remove("Home.nsf")
weird_state_names
# Out:
# ['sufsd']

# %%
boarddocs_df.loc[boarddocs_df['boarddocs_state']=='sufsd',].head()
# Out:
#                                      LEA_NAME    LEAID STATENAME  \
# 17193  SPACKENKILL UNION FREE SCHOOL DISTRICT  3606500  NEW YORK
#
#                                                    url            domain  \
# 17193  https://go.boarddocs.com/sufsd/Board.nsf/Public  go.boarddocs.com
#
#       boarddocs_state boarddocs_lea
# 17193           sufsd     Board.nsf

# %%
# Spackenkill Union Free School District in New York
# OK

# %%
# we will now standardize the URLs to go.boarddocs.com/XX/XXXX/Board.nsf/Public for scrapping
boarddocs_df.sample(5)
# Out:
#                          LEA_NAME    LEAID     STATENAME  \
# 2470      FRANKLIN CO SCHOOL DIST  2801530   MISSISSIPPI
# 13171  RENAISSANCE CHARTER SCHOOL  3600059      NEW YORK
# 1298            Saunemin CCSD 438  1700065      ILLINOIS
# 13834       MaST Community CS III  4200903  PENNSYLVANIA
# 19000                      KONAWA  4016710      OKLAHOMA
#
#                                                                                                                                                  url  \
# 2470                                                                                                                                             NaN
# 13171  https://www.boarddocs.com/fl/palmbeach/Board.nsf/files/A3RJW64DBECA/$file/RenCen%20HS%20of%20PB%20-%20Board%20Notification%20-%2010-28-15.pdf
# 1298                                                                                                                                             NaN
# 13834     https://go.boarddocs.com/mt/kalispell/Board.nsf/files/CWWVTB824194/$file/Kalispell%20Community%20Partnerships%20Charter%20School%20App.pdf
# 19000                       https://go.boarddocs.com/fl/hendry/Board.nsf/files/CV8S7P70FFBC/$file/5.C.%20School_District_Final_Altria_Allocation.pdf
#
#                   domain boarddocs_state boarddocs_lea
# 2470                None            None          None
# 13171  www.boarddocs.com              fl     palmbeach
# 1298                None            None          None
# 13834   go.boarddocs.com              mt     kalispell
# 19000   go.boarddocs.com              fl        hendry

# %%
boarddocs_df.sample(5)
# Out:
#                                                   LEA_NAME    LEAID  \
# 5397                                              Copeland  2005190
# 18615                                Stanly County Schools  3704320
# 5248                                     Oregon City SD 62  4109330
# 18957                                     Seeley Lake Elem  3023730
# 5224   Northern Burlington County Regional School District  3411700
#
#             STATENAME  \
# 5397           KANSAS
# 18615  NORTH CAROLINA
# 5248           OREGON
# 18957         MONTANA
# 5224       NEW JERSEY
#
#                                                                                                                                                                             url  \
# 5397                                                                       https://go.boarddocs.com/fla/vcsfl/Board.nsf/files/9FP3JQ717E5A/$file/Copeland%20Bio%2012-3-2013.pdf
# 18615                                                                                                                     https://go.boarddocs.com/nc/stanlync/Board.nsf/Public
# 5248   https://go.boarddocs.com/or/ocsd62/Board.nsf/files/CLU3SX0854FB/$file/OREGON%20CITY%20ADDITIONAL%20QUOTE%20FORM%20Stepping%20Stones%20SHC%20Procare%20Therapy%202022.pdf
# 18957                                                                                     https://go.boarddocs.com/wa/lwsd/Board.nsf/files/BV4U6S7A90FB/$file/Minutes050100.pdf
# 5224                                                                                                                        https://go.boarddocs.com/nj/nbcrsd/board.nsf/public
#
#                  domain boarddocs_state boarddocs_lea
# 5397   go.boarddocs.com             fla         vcsfl
# 18615  go.boarddocs.com              nc      stanlync
# 5248   go.boarddocs.com              or        ocsd62
# 18957  go.boarddocs.com              wa          lwsd
# 5224   go.boarddocs.com              nj        nbcrsd

# %%
boarddocs_df.loc[~boarddocs_df["boarddocs_state"].isna(), "query_url"] = "https://go.boarddocs.com/" + boarddocs_df["boarddocs_state"] + '/' + boarddocs_df["boarddocs_lea"] + "/Board.nsf/Public"

# %%
# informed by later work in `visit_boarddocs.ipynb`
# we look at those with boarddocs_lea set to Board.nsf
boarddocs_df.loc[boarddocs_df['boarddocs_lea'] == "Board.nsf"]
# Out:
#                                              LEA_NAME    LEAID STATENAME  \
# 6678                     TRI-COUNTY TECHNOLOGY CENTER  4000093  OKLAHOMA
# 7172                                   Screven County  1304500   GEORGIA
# 9457                                  Knox County ESC  3904781      OHIO
# 9638                          Genoa Kingston CUSD 424  1716410  ILLINOIS
# 11086  Butler Technology & Career Development Schools  3905088      OHIO
# 11544                   WES WATKINS TECHNOLOGY CENTER  4000065  OKLAHOMA
# 11642                          Northeast Georgia RESA  1300010   GEORGIA
# 12273                      Kishwaukee Educ Consortium  1700258  ILLINOIS
# 17193          SPACKENKILL UNION FREE SCHOOL DISTRICT  3606500  NEW YORK
# 17905                           Heart of Georgia RESA  1300017   GEORGIA
#
#                                                                                                                                                 url  \
# 6678                                 https://www.boarddocs.com/butler/Board.nsf/legacy-content/85BMP21D4F62/$FILE/Facilities%20Strategic%20Plan.pdf
# 7172                                                       https://www.boarddocs.com/wcps/Board.nsf/legacy-content/87Y65T65066A/$FILE/Min021103.pdf
# 9457   https://go.boarddocs.com/butler/Board.nsf/files/8HTP64630762/$file/March%2018%20Regular%20Meeting%20and%20March%2025%2C%201998%20Minutes.pdf
# 9638                                                                                                https://go.boarddocs.com/genoa/Board.nsf/Public
# 11086                                                                          https://www.boarddocs.com/butler/Board.nsf/goto?open&id=ABULPD570215
# 11544                                       https://go.boarddocs.com/butler/Board.nsf/files/8HESY56FFC3C/$file/October%2011%2C%202000%20Minutes.pdf
# 11642                                             https://www.boarddocs.com/wcps/Board.nsf/legacy-content/87XUQU642EAA/$FILE/ATT4CLAW/Min041806.pdf
# 12273                https://go.boarddocs.com/genoa/Board.nsf/legacy-content/85WJVP121BB0/$FILE/082206%20%20%20Board%20of%20Education%20Minutes.pdf
# 17193                                                                                               https://go.boarddocs.com/sufsd/Board.nsf/Public
# 17905                                             https://www.boarddocs.com/wcps/Board.nsf/legacy-content/87XUQU642EAA/$FILE/ATT4CLAW/Min041806.pdf
#
#                   domain boarddocs_state boarddocs_lea  \
# 6678   www.boarddocs.com          butler     Board.nsf
# 7172   www.boarddocs.com            wcps     Board.nsf
# 9457    go.boarddocs.com          butler     Board.nsf
# 9638    go.boarddocs.com           genoa     Board.nsf
# 11086  www.boarddocs.com          butler     Board.nsf
# 11544   go.boarddocs.com          butler     Board.nsf
# 11642  www.boarddocs.com            wcps     Board.nsf
# 12273   go.boarddocs.com           genoa     Board.nsf
# 17193   go.boarddocs.com           sufsd     Board.nsf
# 17905  www.boarddocs.com            wcps     Board.nsf
#
#                                                         query_url
# 6678   https://go.boarddocs.com/butler/Board.nsf/Board.nsf/Public
# 7172     https://go.boarddocs.com/wcps/Board.nsf/Board.nsf/Public
# 9457   https://go.boarddocs.com/butler/Board.nsf/Board.nsf/Public
# 9638    https://go.boarddocs.com/genoa/Board.nsf/Board.nsf/Public
# 11086  https://go.boarddocs.com/butler/Board.nsf/Board.nsf/Public
# 11544  https://go.boarddocs.com/butler/Board.nsf/Board.nsf/Public
# 11642    https://go.boarddocs.com/wcps/Board.nsf/Board.nsf/Public
# 12273   https://go.boarddocs.com/genoa/Board.nsf/Board.nsf/Public
# 17193   https://go.boarddocs.com/sufsd/Board.nsf/Board.nsf/Public
# 17905    https://go.boarddocs.com/wcps/Board.nsf/Board.nsf/Public

# %%
# in these cases we omit the second title
boarddocs_df.loc[boarddocs_df['boarddocs_lea'] == "Board.nsf", "query_url"] = "https://go.boarddocs.com/" + boarddocs_df["boarddocs_state"] + "/Board.nsf/Public"

# %%
boarddocs_df.sample(5)
# Out:
#                         LEA_NAME    LEAID                   STATENAME  \
# 14266    Menominee Tribal School  5900144  BUREAU OF INDIAN EDUCATION
# 18351       Columbus Grove Local  3904931                        OHIO
# 14752    Treeside Charter School  4900192                        UTAH
# 9264             Yolo County ROP   600149                  CALIFORNIA
# 18576  IN Math & Science Academy  1800067                     INDIANA
#
#                                                                                                                              url  \
# 14266                                                       https://go.boarddocs.com/wi/menind/Board.nsf/Public?open&id=policies
# 18351                                                       https://www.boarddocs.com/oh/colum/Board.nsf/Public?open&id=policies
# 14752                           https://go.boarddocs.com/ut/uen/Board.nsf/files/D29QKJ699BC2/$file/24_UETN_Technology_Report.pdf
# 9264   https://go.boarddocs.com/ca/cottonwood/Board.nsf/files/CE9VK98114C9/$file/ROP%20MOU%202022%20Participating%20District.pdf
# 18576                                                       https://go.boarddocs.com/nc/tmsa/Board.nsf/goto?open&id=B92RJ96DB9B2
#
#                   domain boarddocs_state boarddocs_lea  \
# 14266   go.boarddocs.com              wi        menind
# 18351  www.boarddocs.com              oh         colum
# 14752   go.boarddocs.com              ut           uen
# 9264    go.boarddocs.com              ca    cottonwood
# 18576   go.boarddocs.com              nc          tmsa
#
#                                                      query_url
# 14266      https://go.boarddocs.com/wi/menind/Board.nsf/Public
# 18351       https://go.boarddocs.com/oh/colum/Board.nsf/Public
# 14752         https://go.boarddocs.com/ut/uen/Board.nsf/Public
# 9264   https://go.boarddocs.com/ca/cottonwood/Board.nsf/Public
# 18576        https://go.boarddocs.com/nc/tmsa/Board.nsf/Public

# %%
# percent of duplicated queries
boarddocs_df['query_url'].duplicated().sum() / boarddocs_df.shape[0] * 100
# Out:
# np.float64(82.05937770535215)

# %%
# code from here is informed by later work at `visit_boarddocs.ipynb`

boarddocs_df[boarddocs_df["query_url"] == "https://go.boarddocs.com/mi/wpas/Board.nsf/Public"]
# Out:
#                               LEA_NAME    LEAID STATENAME  \
# 6187  Whittemore-Prescott Area Schools  2636390  MICHIGAN
#
#                                                                        url  \
# 6187  https://go.boarddocs.com/mi/wpas/Board.nsf/goto?open&id=C5JRT75DE77E
#
#                 domain boarddocs_state boarddocs_lea  \
# 6187  go.boarddocs.com              mi          wpas
#
#                                               query_url
# 6187  https://go.boarddocs.com/mi/wpas/Board.nsf/Public

# %%
boarddocs_df[boarddocs_df["query_url"] == "https://go.boarddocs.com/il/tfd215/Board.nsf/Public"]
# Out:
#                        LEA_NAME    LEAID      STATENAME  \
# 19223  Thornton School District  3306660  NEW HAMPSHIRE
#
#                                                                           url  \
# 19223  https://go.boarddocs.com/il/tfd215/Board.nsf/goto?open&id=CDLHZS4AED7D
#
#                  domain boarddocs_state boarddocs_lea  \
# 19223  go.boarddocs.com              il        tfd215
#
#                                                  query_url
# 19223  https://go.boarddocs.com/il/tfd215/Board.nsf/Public

# %%
boarddocs_df[boarddocs_df["query_url"] == "https://go.boarddocs.com/mi/oxf/Board.nsf/Public"]
# Out:
#                        LEA_NAME    LEAID STATENAME  \
# 14253  Oxford Community Schools  2627240  MICHIGAN
#
#                                                     url            domain  \
# 14253  https://go.boarddocs.com/mi/oxf/Board.nsf/Public  go.boarddocs.com
#
#       boarddocs_state boarddocs_lea  \
# 14253              mi           oxf
#
#                                               query_url
# 14253  https://go.boarddocs.com/mi/oxf/Board.nsf/Public

# %%
# choose useful columns and save it
boarddocs_df = boarddocs_df.loc[:, ['LEA_NAME','LEAID','STATENAME','query_url']]
output_filename = "boarddocs_url_cleaned.csv"
boarddocs_df.to_csv(output_filename, index=False)

# %%
# Out:
#                               LEA_NAME    LEAID STATENAME  \
# 6187  Whittemore-Prescott Area Schools  2636390  MICHIGAN
#
#                                               query_url
# 6187  https://go.boarddocs.com/mi/wpas/Board.nsf/Public
