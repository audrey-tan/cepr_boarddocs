# %% [markdown]
# This notebook organizes the s_tokens into actual simbli URLs, along with the school name and state.
#
# Input
# - `s_tokens.json`
#
# Output
# - `simbli_urls.csv`

# %%
import pandas as pd

df = pd.read_json("s_tokens.json")
df.head()
# Out:
#                            2                      4               6         \
# 0  Kirksville R-III School District  North Andrew Co. R-VI  Savannah R-III
# 1                                MO                     MO              MO
#
#                             10           11                         12        \
# 0  Alamance-Burlington School System  Van-Far R-I  Mexico Public Schools #59
# 1                                 NC           MO                         MO
#
#         14           15              16          19        ...  \
# 0  Southwest R-V  Exeter R-VI  Cassville R-IV  Monett R-I  ...
# 1             MO           MO              MO          MO  ...
#
#              36031823         36031824             36031825  \
# 0  George-Little Rock  Centerville CSD  Central Decatur CSD
# 1                  IA               IA                   IA
#
#                             36031826          36031827  \
# 0  Bedford Community School District  Boyer Valley CSD
# 1                                 IA                IA
#
#                                    36031828 36031829      36031830  \
# 0  Sequoia Union Elementary School District  GMG CSD  Glenwood CSD
# 1                                        CA       IA            IA
#
#                              36031831          36031832
# 0  Atlantic Community School District  Garden Grove USD
# 1                                  IA                CA
#
# [2 rows x 2016 columns]

# %%
# transpose it
df = df.transpose()
df.head()
# Out:
#                                     0   1
# 2    Kirksville R-III School District  MO
# 4               North Andrew Co. R-VI  MO
# 6                      Savannah R-III  MO
# 10  Alamance-Burlington School System  NC
# 11                        Van-Far R-I  MO

# %%
# name the columns
df["s_token"] = df.index
df.head()
# Out:
#                                     0   1  s_token
# 2    Kirksville R-III School District  MO        2
# 4               North Andrew Co. R-VI  MO        4
# 6                      Savannah R-III  MO        6
# 10  Alamance-Burlington School System  NC       10
# 11                        Van-Far R-I  MO       11

# %%
df = df.rename(columns={
    0: "school_district",
    1: "state"
})
df.head()
# Out:
#                       school_district state  s_token
# 2    Kirksville R-III School District    MO        2
# 4               North Andrew Co. R-VI    MO        4
# 6                      Savannah R-III    MO        6
# 10  Alamance-Burlington School System    NC       10
# 11                        Van-Far R-I    MO       11

# %%
# add URLs
df["simbli_url"] = "https://simbli.eboardsolutions.com/SB_Meetings/SB_MeetingListing.aspx?S=" + df["s_token"].astype(str)
df.head()
# Out:
#                       school_district state  s_token  \
# 2    Kirksville R-III School District    MO        2
# 4               North Andrew Co. R-VI    MO        4
# 6                      Savannah R-III    MO        6
# 10  Alamance-Burlington School System    NC       10
# 11                        Van-Far R-I    MO       11
#
#                                            simbli_url
# 2   https://simbli.eboardsolutions.com/SB_Meetings...
# 4   https://simbli.eboardsolutions.com/SB_Meetings...
# 6   https://simbli.eboardsolutions.com/SB_Meetings...
# 10  https://simbli.eboardsolutions.com/SB_Meetings...
# 11  https://simbli.eboardsolutions.com/SB_Meetings...

# %%
# drop the s_token column
df = df.drop("s_token", axis=1)
df.head()
# Out:
#                       school_district state  \
# 2    Kirksville R-III School District    MO
# 4               North Andrew Co. R-VI    MO
# 6                      Savannah R-III    MO
# 10  Alamance-Burlington School System    NC
# 11                        Van-Far R-I    MO
#
#                                            simbli_url
# 2   https://simbli.eboardsolutions.com/SB_Meetings...
# 4   https://simbli.eboardsolutions.com/SB_Meetings...
# 6   https://simbli.eboardsolutions.com/SB_Meetings...
# 10  https://simbli.eboardsolutions.com/SB_Meetings...
# 11  https://simbli.eboardsolutions.com/SB_Meetings...

# %%
# export
df.to_csv("simbli_urls.csv", index=False)
